# %%
import sqlite3
from interchange.persistence.database import Database

db = Database()
# Out:
# 2025-11-25 16:05:21,191 :: PID 23124 :: TID 34860 :: database._create_connection :: Line 33 :: DEBUG :: Connected to SQLite database
# 2025-11-25 16:05:21,195 :: PID 23124 :: TID 34860 :: database._close_connection :: Line 44 :: DEBUG :: Closed connection to SQLite database

# %%
sql_statement = "DROP TABLE IF EXISTS visa_transaction_type;"
query = db._execute(sql_statement)
query
# Out:
# 2025-11-25 15:55:23,695 :: PID 23124 :: TID 34860 :: database._execute :: Line 57 :: DEBUG :: SQL statement executed successfully
# []

# %%
sql_statement = "CREATE TABLE visa_transaction_type ( business_transaction_type_id TEXT NOT NULL, business_transaction_type_code TEXT NOT NULL,short_description TEXT, long_description TEXT, transaction_type_id TEXT);"
query = db._execute(sql_statement)
query
# Out:
# 2025-11-25 15:55:39,742 :: PID 23124 :: TID 34860 :: database._execute :: Line 57 :: DEBUG :: SQL statement executed successfully
# []

# %%
data = [
    ("0", " ", "Not Apply", "Not Apply", "UNK"),
    ("1", "100", "Purchase", "Purchase", "PUR"),
    ("2", "110", "VisaPhone", "VisaPhone", "PUR"),
    ("4", "140", "DDS On-Us", "DDS On-Us", "UNK"),
    ("5", "141", "DDS Participate", "DDS Participate", "UNK"),
    ("6", "142", "DDS Merchant Issuer", "DDS Merchant Issuer", "PUR"),
    ("7", "150", "NYCE purchase", "NYCE purchase", "PUR"),
    ("8", "151", "PULSE purchase", "PULSE purchase", "PUR"),
    ("9", "152", "STAR purchase", "STAR purchase", "PUR"),
    ("10", "160", "NYCE merch return", "NYCE merch return", "PUR"),
    ("11", "161", "PULSE merch return", "PULSE merch return", "PUR"),
    ("12", "162", "STAR merch return", "STAR merch return", "PUR"),
    ("13", "170", "NYCE preauth", "NYCE preauth", "PUR"),
    ("14", "171", "PULSE preauth", "PULSE preauth", "PUR"),
    ("15", "172", "STAR preauth", "STAR preauth", "PUR"),
    ("16", "180", "NYCE decline", "NYCE decline", "UNK"),
    ("17", "181", "PULSE decline", "PULSE decline", "UNK"),
    ("18", "182", "STAR decline", "STAR decline", "UNK"),
    ("21", "300", "Manual Cash", "Manual Cash", "CSH"),
    ("22", "310", "ATM Cash", "ATM Cash", "CSH"),
    ("23", "311", "ATM Deposits", "ATM Deposits", "CSH"),
    ("24", "320", "POS Check", "POS Check", "UNK"),
    ("26", "400", "Payment Order Sendback", "Payment Order Sendback", "CSH"),
    ("27", "410", "Payment Order", "Payment Order", "CSH"),
    ("28", "420", "Payment Order Notification", "Payment Order Notification", "CSH"),
    ("29", "430", "Prepaid Loads /Reloads", "Prepaid Loads /Reloads", "UNK"),
    ("31", "500", "Fee Collection rc=0100", "Fee Collection rc=0100", "UNK"),
    ("32", "501", "Fee Collection rc=0110", "Fee Collection rc=0110", "UNK"),
    ("33", "502", "Fee Collection rc=0130", "Fee Collection rc=0130", "UNK"),
    ("34", "503", "Fee Collection rc=0140", "Fee Collection rc=0140", "UNK"),
    ("35", "504", "Fee Collection rc=0150", "Fee Collection rc=0150", "UNK"),
    ("36", "505", "Fee Collection rc=0160", "Fee Collection rc=0160", "UNK"),
    ("37", "506", "Fee Collection rc=0170", "Fee Collection rc=0170", "UNK"),
    ("38", "507", "Fee Collection rc=0190", "Fee Collection rc=0190", "UNK"),
    ("39", "508", "Fee Collection rc=0200", "Fee Collection rc=0200", "UNK"),
    ("40", "509", "Fee Collection rc=0210", "Fee Collection rc=0210", "UNK"),
    ("41", "510", "Fee Collection rc=0220", "Fee Collection rc=0220", "UNK"),
    ("42", "511", "Fee Collection rc=0230", "Fee Collection rc=0230", "UNK"),
    ("43", "512", "Fee Collection rc=0240", "Fee Collection rc=0240", "UNK"),
    ("44", "513", "Fee Collection rc=0300", "Fee Collection rc=0300", "UNK"),
    ("45", "514", "Fee Collection rc=0350", "Fee Collection rc=0350", "UNK"),
    ("46", "515", "Fee Collection rc=0370", "Fee Collection rc=0370", "UNK"),
    ("47", "516", "Fee Collection rc=0390", "Fee Collection rc=0390", "UNK"),
    ("48", "517", "Fee Collection rc=0400", "Fee Collection rc=0400", "UNK"),
    ("49", "518", "Fee Collection rc=5000", "Fee Collection rc=5000", "UNK"),
    ("50", "519", "Fee Collection rc=5010", "Fee Collection rc=5010", "UNK"),
    ("51", "520", "Fee Collection rc=5015", "Fee Collection rc=5015", "UNK"),
    ("52", "521", "Fee Collection rc=5020", "Fee Collection rc=5020", "UNK"),
    ("53", "522", "Fee Collection rc=5030", "Fee Collection rc=5030", "UNK"),
    ("54", "523", "Fee Collection rc=5040", "Fee Collection rc=5040", "UNK"),
    ("55", "524", "Fee Collection rc=5050", "Fee Collection rc=5050", "UNK"),
    ("56", "525", "Fee Collection rc=5060", "Fee Collection rc=5060", "UNK"),
    ("57", "526", "Fee Collection rc=5080", "Fee Collection rc=5080", "UNK"),
    ("58", "527", "Fee Collection rc=5090", "Fee Collection rc=5090", "UNK"),
    ("59", "528", "Fee Collection rc=5100", "Fee Collection rc=5100", "UNK"),
    ("60", "529", "Fee Collection rc=5110", "Fee Collection rc=5110", "UNK"),
    ("61", "530", "Fee Collection rc=5120", "Fee Collection rc=5120", "UNK"),
    ("62", "531", "Fee Collection rc=5130", "Fee Collection rc=5130", "UNK"),
    ("63", "532", "Fee Collection rc=5140", "Fee Collection rc=5140", "UNK"),
    ("64", "533", "Fee Collection rc=5150", "Fee Collection rc=5150", "UNK"),
    ("65", "534", "Fee Collection rc=5160", "Fee Collection rc=5160", "UNK"),
    ("66", "535", "Fee Collection rc=5165", "Fee Collection rc=5165", "UNK"),
    ("67", "536", "Fee Collection rc=5170", "Fee Collection rc=5170", "UNK"),
    ("68", "537", "Fee Collection rc=5180", "Fee Collection rc=5180", "UNK"),
    ("69", "538", "Fee Collection rc=5185", "Fee Collection rc=5185", "UNK"),
    ("70", "539", "Fee Collection rc=5190", "Fee Collection rc=5190", "UNK"),
    ("71", "540", "Fee Collection rc=5195", "Fee Collection rc=5195", "UNK"),
    ("72", "541", "Fee Collection rc=5210", "Fee Collection rc=5210", "UNK"),
    ("73", "542", "Fee Collection rc=5240", "Fee Collection rc=5240", "UNK"),
    ("74", "543", "Fee Collection rc=5245", "Fee Collection rc=5245", "UNK"),
    ("75", "544", "Fee Collection rc=5250", "Fee Collection rc=5250", "UNK"),
    ("76", "545", "Fee Collection rc=5260", "Fee Collection rc=5260", "UNK"),
    ("77", "546", "Fee Collection rc=5270", "Fee Collection rc=5270", "UNK"),
    ("78", "547", "Fee Collection rc=5280", "Fee Collection rc=5280", "UNK"),
    ("79", "548", "Fee Collection rc=5282", "Fee Collection rc=5282", "UNK"),
    ("80", "549", "Fee Collection rc=5284", "Fee Collection rc=5284", "UNK"),
    ("3", "120", "Quasi-cash", "Quasi-cash", "PUR"),
    ("30", "440", "Account Payment", "Account Payment", "PUR"),
    ("81", "550", "Fee Collection rc=5286", "Fee Collection rc=5286", "UNK"),
    ("82", "551", "Fee Collection rc=5290", "Fee Collection rc=5290", "UNK"),
    ("83", "552", "Fee Collection rc=5300", "Fee Collection rc=5300", "UNK"),
    ("84", "553", "Fee Collection rc=1220", "Fee Collection rc=1220", "UNK"),
    ("85", "554", "Fee Collection rc=1350", "Fee Collection rc=1350", "UNK"),
    ("86", "555", "Fee Collection rc=0250", "Fee Collection rc=0250", "UNK"),
    ("87", "556", "Fee Collection rc=1221", "Fee Collection rc=1221", "UNK"),
    ("88", "557", "Fee Collection rc=1222", "Fee Collection rc=1222", "UNK"),
    ("89", "558", "Fee Collection rc=5320", "Fee Collection rc=5320", "UNK"),
    ("90", "559", "Fee Collection rc=5310", "Fee Collection rc=5310", "UNK"),
    ("91", "560", "Fee Collection rc=5330", "Fee Collection rc=5330", "UNK"),
    ("92", "561", "Fee Collection rc=5340", "Fee Collection rc=5340", "UNK"),
    ("93", "562", "Fee Collection rc=5350", "Fee Collection rc=5350", "UNK"),
    ("94", "563", "Fee Collection rc=5360", "Fee Collection rc=5360", "UNK"),
    ("95", "570", "VISA extra rc=6000", "VISA extra rc=6000", "UNK"),
    ("96", "571", "VISA extra rc=6010", "VISA extra rc=6010", "UNK"),
    ("97", "572", "VISA extra rc=6020", "VISA extra rc=6020", "UNK"),
    ("98", "573", "VISA extra rc=6030", "VISA extra rc=6030", "UNK"),
    ("99", "574", "VISA extra rc=6040", "VISA extra rc=6040", "UNK"),
    ("100", "575", "VISA extra rc=6050", "VISA extra rc=6050", "UNK"),
    ("101", "576", "VISA extra rc=6060", "VISA extra rc=6060", "UNK"),
    ("102", "577", "VISA extra rc=6070", "VISA extra rc=6070", "UNK"),
    ("103", "578", "Cardholder fee rc=6100", "Cardholder fee rc=6100", "UNK"),
    ("104", "579", "Cardholder fee rc=6110", "Cardholder fee rc=6110", "UNK"),
    ("105", "580", "Cardholder fee rc=6120", "Cardholder fee rc=6120", "UNK"),
    ("106", "581", "Cardholder fee rc=6130", "Cardholder fee rc=6130", "UNK"),
    ("107", "582", "VISA extra rc=6080", "VISA extra rc=6080", "UNK"),
    ("108", "583", "VISA extra rc=6085", "VISA extra rc=6085", "UNK"),
    ("109", "584", "Fee Collection rc=6140", "Fee Collection rc=6140", "UNK"),
    ("110", "585", "Fee Collection rc=6150", "Fee Collection rc=6150", "UNK"),
    ("111", "586", "Fee Collection rc=6160", "Fee Collection rc=6160", "UNK"),
    ("112", "587", "Fee Collection rc=6170", "Fee Collection rc=6170", "UNK"),
    ("113", "588", "Fee Collection rc=0401", "Fee Collection rc=0401", "UNK"),
    ("114", "589", "Fee Collection rc=0402", "Fee Collection rc=0402", "UNK"),
    ("115", "599", "Fee Collection rc=Other", "Fee Collection rc=Other", "UNK"),
    ("116", "600", "Funds Disbursement rc=0100", "Funds Disbursement rc=0100", "UNK"),
    ("117", "601", "Funds Disbursement rc=0110", "Funds Disbursement rc=0110", "UNK"),
    ("118", "602", "Funds Disbursement rc=0130", "Funds Disbursement rc=0130", "UNK"),
    ("119", "603", "Funds Disbursement rc=0140", "Funds Disbursement rc=0140", "UNK"),
    ("120", "604", "Funds Disbursement rc=0150", "Funds Disbursement rc=0150", "UNK"),
    ("121", "605", "Funds Disbursement rc=0160", "Funds Disbursement rc=0160", "UNK"),
    ("122", "606", "Funds Disbursement rc=0170", "Funds Disbursement rc=0170", "UNK"),
    ("123", "607", "Funds Disbursement rc=0190", "Funds Disbursement rc=0190", "UNK"),
    ("124", "608", "Funds Disbursement rc=0200", "Funds Disbursement rc=0200", "UNK"),
    ("125", "609", "Funds Disbursement rc=0210", "Funds Disbursement rc=0210", "UNK"),
    ("126", "610", "Funds Disbursement rc=0220", "Funds Disbursement rc=0220", "UNK"),
    ("127", "611", "Funds Disbursement rc=0230", "Funds Disbursement rc=0230", "UNK"),
    ("128", "612", "Funds Disbursement rc=0240", "Funds Disbursement rc=0240", "UNK"),
    ("129", "613", "Funds Disbursement rc=0300", "Funds Disbursement rc=0300", "UNK"),
    ("130", "614", "Funds Disbursement rc=0350", "Funds Disbursement rc=0350", "UNK"),
    ("131", "615", "Funds Disbursement rc=0370", "Funds Disbursement rc=0370", "UNK"),
    ("132", "616", "Funds Disbursement rc=0390", "Funds Disbursement rc=0390", "UNK"),
    ("133", "617", "Funds Disbursement rc=0400", "Funds Disbursement rc=0400", "UNK"),
    ("134", "618", "Funds Disbursement rc=5000", "Funds Disbursement rc=5000", "UNK"),
    ("135", "619", "Funds Disbursement rc=5010", "Funds Disbursement rc=5010", "UNK"),
    ("136", "620", "Funds Disbursement rc=5015", "Funds Disbursement rc=5015", "UNK"),
    ("137", "621", "Funds Disbursement rc=5020", "Funds Disbursement rc=5020", "UNK"),
    ("138", "622", "Funds Disbursement rc=5030", "Funds Disbursement rc=5030", "UNK"),
    ("139", "623", "Funds Disbursement rc=5040", "Funds Disbursement rc=5040", "UNK"),
    ("140", "624", "Funds Disbursement rc=5050", "Funds Disbursement rc=5050", "UNK"),
    ("141", "625", "Funds Disbursement rc=5060", "Funds Disbursement rc=5060", "UNK"),
    ("142", "626", "Funds Disbursement rc=5080", "Funds Disbursement rc=5080", "UNK"),
    ("143", "627", "Funds Disbursement rc=5090", "Funds Disbursement rc=5090", "UNK"),
    ("144", "628", "Funds Disbursement rc=5100", "Funds Disbursement rc=5100", "UNK"),
    ("145", "629", "Funds Disbursement rc=5110", "Funds Disbursement rc=5110", "UNK"),
    ("146", "630", "Funds Disbursement rc=5120", "Funds Disbursement rc=5120", "UNK"),
    ("147", "631", "Funds Disbursement rc=5130", "Funds Disbursement rc=5130", "UNK"),
    ("148", "632", "Funds Disbursement rc=5140", "Funds Disbursement rc=5140", "UNK"),
    ("149", "633", "Funds Disbursement rc=5150", "Funds Disbursement rc=5150", "UNK"),
    ("150", "634", "Funds Disbursement rc=5160", "Funds Disbursement rc=5160", "UNK"),
    ("151", "635", "Funds Disbursement rc=5165", "Funds Disbursement rc=5165", "UNK"),
    ("152", "636", "Funds Disbursement rc=5170", "Funds Disbursement rc=5170", "UNK"),
    ("153", "637", "Funds Disbursement rc=5180", "Funds Disbursement rc=5180", "UNK"),
    ("154", "638", "Funds Disbursement rc=5185", "Funds Disbursement rc=5185", "UNK"),
    ("155", "639", "Funds Disbursement rc=5190", "Funds Disbursement rc=5190", "UNK"),
    ("156", "640", "Funds Disbursement rc=5195", "Funds Disbursement rc=5195", "UNK"),
    ("157", "641", "Funds Disbursement rc=5210", "Funds Disbursement rc=5210", "UNK"),
    ("158", "642", "Funds Disbursement rc=5240", "Funds Disbursement rc=5240", "UNK"),
    ("159", "643", "Funds Disbursement rc=5245", "Funds Disbursement rc=5245", "UNK"),
    ("160", "644", "Funds Disbursement rc=5250", "Funds Disbursement rc=5250", "UNK"),
    ("161", "645", "Funds Disbursement rc=5260", "Funds Disbursement rc=5260", "UNK"),
    ("162", "646", "Funds Disbursement rc=5270", "Funds Disbursement rc=5270", "UNK"),
    ("163", "647", "Funds Disbursement rc=5280", "Funds Disbursement rc=5280", "UNK"),
    ("164", "648", "Funds Disbursement rc=5282", "Funds Disbursement rc=5282", "UNK"),
    ("165", "649", "Funds Disbursement rc=5284", "Funds Disbursement rc=5284", "UNK"),
    ("166", "650", "Funds Disbursement rc=5286", "Funds Disbursement rc=5286", "UNK"),
    ("167", "651", "Funds Disbursement rc=5290", "Funds Disbursement rc=5290", "UNK"),
    ("168", "652", "Funds Disbursement rc=5300", "Funds Disbursement rc=5300", "UNK"),
    ("169", "653", "Funds Disbursement rc=1220", "Funds Disbursement rc=1220", "UNK"),
    ("170", "654", "Funds Disbursement rc=1350", "Funds Disbursement rc=1350", "UNK"),
    ("171", "655", "Funds Disbursement rc=0250", "Funds Disbursement rc=0250", "UNK"),
    ("172", "656", "Funds Disbursement rc=1221", "Funds Disbursement rc=1221", "UNK"),
    ("173", "657", "Funds Disbursement rc=1222", "Funds Disbursement rc=1222", "UNK"),
    ("174", "658", "Funds Disbursement rc=5320", "Funds Disbursement rc=5320", "UNK"),
    ("175", "659", "Funds Disbursement rc=5310", "Funds Disbursement rc=5310", "UNK"),
    ("176", "660", "Funds Disbursement rc=5330", "Funds Disbursement rc=5330", "UNK"),
    ("177", "661", "Funds Disbursement rc=5340", "Funds Disbursement rc=5340", "UNK"),
    ("178", "662", "Funds Disbursement rc=5350", "Funds Disbursement rc=5350", "UNK"),
    ("179", "663", "Funds Disbursement rc=5360", "Funds Disbursement rc=5360", "UNK"),
    ("180", "670", "VISA extra rc=6000", "VISA extra rc=6000", "UNK"),
    ("181", "671", "VISA extra rc=6010", "VISA extra rc=6010", "UNK"),
    ("182", "672", "VISA extra rc=6020", "VISA extra rc=6020", "UNK"),
    ("183", "673", "VISA extra rc=6030", "VISA extra rc=6030", "UNK"),
    ("184", "674", "VISA extra rc=6040", "VISA extra rc=6040", "UNK"),
    ("185", "675", "VISA extra rc=6050", "VISA extra rc=6050", "UNK"),
    ("186", "676", "VISA extra rc=6060", "VISA extra rc=6060", "UNK"),
    ("187", "677", "VISA extra rc=6070", "VISA extra rc=6070", "UNK"),
    ("188", "678", "Rebate credit rc=6100", "Rebate credit rc=6100", "UNK"),
    ("189", "679", "Rebate credit rc=6110", "Rebate credit rc=6110", "UNK"),
    ("190", "680", "Rebate credit rc=6120", "Rebate credit rc=6120", "UNK"),
    ("191", "681", "Rebate credit rc=6130", "Rebate credit rc=6130", "UNK"),
    ("192", "682", "VISA extra rc=6080", "VISA extra rc=6080", "UNK"),
    ("193", "683", "VISA extra rc=6085", "VISA extra rc=6085", "UNK"),
    ("194", "684", "Funds Disbursement rc=6140", "Funds Disbursement rc=6140", "UNK"),
    ("195", "685", "Funds Disbursement rc=6150", "Funds Disbursement rc=6150", "UNK"),
    ("196", "686", "Funds Disbursement rc=6160", "Funds Disbursement rc=6160", "UNK"),
    ("197", "687", "Funds Disbursement rc=6170", "Funds Disbursement rc=6170", "UNK"),
    ("198", "688", "Funds Disbursement rc=0401", "Funds Disbursement rc=0401", "UNK"),
    ("199", "689", "Funds Disbursement rc=0402", "Funds Disbursement rc=0402", "UNK"),
    ("200", "699", "Funds Disbursement rc=Other", "Funds Disbursement rc=Other", "UNK"),
    ("201", "701", "Returned Item", "Returned Item", "UNK"),
    ("202", "702", "Returned Item", "Returned Item", "UNK"),
    ("203", "703", "Returned Item", "Returned Item", "UNK"),
    ("204", "704", "Reclassification Advice", "Reclassification Advice", "UNK"),
    ("205", "730", "ICS Outgoing/Query", "ICS Outgoing/Query", "UNK"),
    ("206", "731", "ICS Incoming/Resp", "ICS Incoming/Resp", "UNK"),
    ("207", "732", "Risk Management", "Risk Management", "UNK"),
    ("208", "733", "Multipurpose Message", "Multipurpose Message", "UNK"),
    ("209", "738", "Request For Copy", "Request For Copy", "UNK"),
    ("210", "739", "RFC Fulfillment", "RFC Fulfillment", "UNK"),
    ("211", "740", "Fraud Advice", "Fraud Advice", "UNK"),
    ("212", "742", "Merch File Upd (Mand)", "Merch File Upd (Mand)", "UNK"),
    ("213", "743", "Merch File Upd (Opt)", "Merch File Upd (Opt)", "UNK"),
    ("214", "744", "Batch Acknowledgment", "Batch Acknowledgment", "UNK"),
    ("215", "745", "General Delivery Rpts", "General Delivery Rpts", "UNK"),
    ("216", "746", "Sett Rpts (Mach Read)", "Sett Rpts (Mach Read)", "UNK"),
    ("217", "747", "Sett Rpts (Print Imag)", "Sett Rpts (Print Imag)", "UNK"),
    ("218", "748", "BASE I Advice Records", "BASE I Advice Records", "UNK"),
    ("219", "750", "Text Message", "Text Message", "UNK"),
    ("220", "751", "Request For Original", "Request For Original", "UNK"),
    ("221", "752", "Request For Photocopy", "Request For Photocopy", "UNK"),
    ("222", "753", "Confirmation Request", "Confirmation Request", "UNK"),
    ("223", "754", "Table Updates", "Table Updates", "UNK"),
    ("224", "755", "RCRF Updates", "RCRF Updates", "UNK"),
    ("225", "756", "Currency Conv Rate Upd", "Currency Conv Rate Upd", "UNK"),
    ("226", "757", "Data Capture Advice", "Data Capture Advice", "UNK"),
    ("227", "758", "National Sett Adv", "National Sett Adv", "UNK"),
    ("228", "759", "Interface Advice", "Interface Advice", "UNK"),
    ("229", "760", "VISA extras fee msg", "VISA extras fee msg", "UNK"),
    ("230", "761", "Prepaid Non-Financials", "Prepaid Non-Financials", "UNK"),
    ("231", "800", "POS Authorization", "POS Authorization", "UNK"),
    ("232", "801", "POS Preauthorization", "POS Preauthorization", "UNK"),
    ("233", "802", "POS Balance Inquiry", "POS Balance Inquiry", "UNK"),
    ("234", "803", "POS Authorization Reversal", "POS Authorization Reversal", "UNK"),
    (
        "235",
        "804",
        "POS Preauthorization Reversal",
        "POS Preauthorization Reversal",
        "UNK",
    ),
    ("236", "806", "POS Decline", "POS Decline", "UNK"),
    ("237", "810", "DDS On-Us Preauthorization", "DDS On-Us Preauthorization", "UNK"),
    ("238", "811", "DDS On-Us Decline", "DDS On-Us Decline", "UNK"),
    (
        "239",
        "812",
        "DDS Participant Preauthorization",
        "DDS Participant Preauthorization",
        "UNK",
    ),
    ("240", "813", "DDS Participant Decline", "DDS Participant Decline", "UNK"),
    ("241", "814", "DDS MIS Preauthorization", "DDS MIS Preauthorization", "UNK"),
    ("242", "815", "DDS MIS Decline", "DDS MIS Decline", "UNK"),
    (
        "243",
        "816",
        "DDS Acquirer Specified Destination",
        "DDS Acquirer Specified Destination",
        "UNK",
    ),
    ("244", "820", "Member Sweepstakes", "Member Sweepstakes", "UNK"),
    ("245", "821", "Visa Sweepstakes", "Visa Sweepstakes", "UNK"),
    ("246", "850", "ATM Authorization", "ATM Authorization", "CSH"),
    ("247", "852", "ATM Balance Inquiry", "ATM Balance Inquiry", "UNK"),
    ("248", "853", "ATM Authorization Reversal", "ATM Authorization Reversal", "UNK"),
    ("249", "856", "ATM Decline", "ATM Decline", "UNK"),
    ("251", "858", "ATM Pin Change", "ATM Pin Change", "UNK"),
    ("252", "859", "ATM PIN Unblock", "ATM PIN Unblock", "UNK"),
    ("253", "862", "Visa ePay Balance Inquiry", "Visa ePay Balance Inquiry", "CSH"),
    ("254", "867", "Visa ePay Transfer", "Visa ePay Transfer", "CSH"),
    ("255", "870", "File Maintenance", "File Maintenance", "UNK"),
    ("25", "330", "Original Credit", "Original Credit", "CRD"),
    ("19", "200", "Merchandise Credit", "Merchandise Credit", "CRD"),
    ("20", "210", "Quasi-cash Credit", "Quasi-cash Credit", "CRD"),
    ("250", "857", "ATM Transfer", "ATM Transfer", "CSH"),
]
sql = """
INSERT INTO visa_transaction_type
(business_transaction_type_id, business_transaction_type_code, short_description, long_description, transaction_type_id)
VALUES (?, ?, ?, ?, ?)
"""
conn = sqlite3.connect("persistence/backup/interchange.db")
cur = conn.cursor()
cur.executemany(sql, data)
conn.commit()
